# %% [markdown]
# <a href="https://colab.research.google.com/github/EllaEstrellaM/ZDO-fourier/blob/main/zdo_restauration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt

from skimage import data
import skimage.io
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = skimage.io.imread("http://www.imagemagick.org/Usage/fourier/twigs.jpg", as_gray=True)
plt.imshow(img, cmap='gray')
img.shape
# Out:
# (256, 256)

# %% [markdown]
# # LO-PASS
